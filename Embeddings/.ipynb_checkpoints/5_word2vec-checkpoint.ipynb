# %% [markdown]
# ##### Word2Vec 论文， udacity 代码， Tensorflow 实现， 牛津大学作业
# ##### gensuim 的 API 接口
# ##### word2vec 的应用

# %% [markdown]
# Deep Learning for word2vec
# =============
# The goal of this project is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'originated', 'a', 'anarchism', 'of', 'term', 'as', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.292292
# Nearest to if: mansfield, bugzilla, sher, concordat, etruria, stimulation, creations, resource,
# Nearest to had: slapping, seeded, married, graduating, racehorse, acc, duron, ailing,
# Nearest to two: wenzel, brahmaputra, poisonous, indigo, reverses, rack, fermented, hemingway,
# Nearest to with: denis, imperium, tro, airstrips, meribbaal, darrow, hosni, exclusive,
# Nearest to was: canonic, debut, herr, jedwabne, namco, rosenzweig, aise, pennsylvania,
# Nearest to to: dern, eighteen, covers, pottery, flanders, lawless, automotive, puente,
# Nearest to new: heydrich, ona, imitating, allende, nautical, parachutes, applescript, phenomenological,
# Nearest to its: juxtaposition, duct, modernize, banishment, limestone, helix, salvaged, punish,
# Nearest to into: aldehydes, gradients, bronzes, interpersonal, rafael, worthless, speeds, wiens,
# Nearest to nine: neurologist, bronfman, argumentum, fpu, alkaloids, angus, automatically, stop,
# Nearest to these: pentecostal, stewed, crt, denison, push, passau, nuclides, benin,
# Nearest to which: collection, nixon, nakano, anatta, westerly, gs, wwi, converse,
# Nearest to most: tirpitz, useable, cosmopolitan, tyrannosaurus, fits, breaks, situs, phenomena,
# Nearest to use: untenable, dropping, assignments, structured, gegen, murdock, unpaired, cast,
# Nearest to are: katakana, exits, infallible, originals, oblast, jaynes, founding, dealer,
# Nearest to between: encyclical, qaddafi, bryn, outcomes, neoplatonism, vs, hermann, corpus,
# Average loss at step 2000: 4.366535
# Average loss at step 4000: 3.865621
# Average loss at step 6000: 3.783616
# Average loss at step 8000: 3.685263
# Average loss at step 10000: 3.616402
# Nearest to if: etruria, mansfield, creations, hyped, bugzilla, sher, acquires, subdued,
# Nearest to had: have, has, was, married, maesa, eduskunta, were, khz,
# Nearest to two: five, three, four, six, eight, seven, one, zero,
# Nearest to with: in, during, blurry, on, using, for, gorillaz, by,
# Nearest to was: is, were, has, had, glas, by, be, are,
# Nearest to to: implicate, screenshot, sumter, would, not, badly, grand, polar,
# Nearest to new: heydrich, maximian, dreadful, ona, gripped, ovid, warcraft, flow,
# Nearest to its: his, the, their, teodoro, systems, duct, inordinate, fern,
# Nearest to into: bronzes, aldehydes, gradients, as, wiens, at, intensification, dartmoor,
# Nearest to nine: eight, five, six, seven, zero, four, three, two,
# Nearest to these: remaining, pentecostal, dismantling, shot, their, crt, denison, all,
# Nearest to which: also, that, it, who, this, ili, heine, prize,
# Nearest to most: achieve, university, situs, asteroids, erode, kabbalistic, bedding, ar,
# Nearest to use: choreographer, stills, sargon, cast, unpaired, momentary, murdock, structured,
# Nearest to are: were, is, was, observes, sophomore, have, infallible, derivative,
# Nearest to between: in, clusters, with, clifton, hermann, outcomes, qaddafi, vs,
# Average loss at step 12000: 3.602006
# Average loss at step 14000: 3.575017
# Average loss at step 16000: 3.408891
# Average loss at step 18000: 3.456083
# Average loss at step 20000: 3.536267
# Nearest to if: etruria, mansfield, hyped, gba, since, when, subdued, posture,
# Nearest to had: has, have, was, were, married, nessie, been, eduskunta,
# Nearest to two: five, three, four, six, seven, zero, one, eight,
# Nearest to with: between, nicotine, sour, in, during, fukuoka, justify, by,
# Nearest to was: is, were, has, had, became, occurred, glas, are,
# Nearest to to: implicate, would, may, might, will, recluse, could, can,
# Nearest to new: maximian, ona, heydrich, ovid, plead, flow, vickers, dreadful,
# Nearest to its: their, his, the, hearn, duct, systems, teodoro, sojourn,
# Nearest to into: from, at, dartmoor, intensification, bronzes, identifications, ditches, underarm,
# Nearest to nine: eight, six, seven, four, five, zero, three, two,
# Nearest to these: many, some, all, their, several, most, which, his,
# Nearest to which: this, that, who, also, it, there, but, marker,
# Nearest to most: more, many, university, some, among, these, hieroglyph, rockall,
# Nearest to use: choreographer, stills, sargon, lanterns, example, brugge, murdock, hard,
# Nearest to are: were, have, is, was, fascism, be, sophomore, amiable,
# Nearest to between: with, in, from, at, christy, specialise, clifton, vedic,
# Average loss at step 22000: 3.501832
# Average loss at step 24000: 3.490049
# Average loss at step 26000: 3.481557
# Average loss at step 28000: 3.479785
# Average loss at step 30000: 3.502911
# Nearest to if: when, though, although, etruria, until, since, mansfield, where,
# Nearest to had: have, has, was, were, gave, nessie, occurred, having,
# Nearest to two: three, four, five, one, eight, seven, six, nine,
# Nearest to with: between, for, including, nicotine, when, by, zeitgeist, using,
# Nearest to was: is, were, has, had, became, when, by, been,
# Nearest to to: would, implicate, screenshot, will, may, amazonas, for, covers,
# Nearest to new: maximian, religious, heydrich, metal, profiled, ovid, flow, aragorn,
# Nearest to its: their, his, the, her, defies, hearn, blatantly, plosives,
# Nearest to into: from, dartmoor, through, intensification, bronzes, underarm, theroux, incestuous,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to these: some, many, all, several, such, their, they, are,
# Nearest to which: this, that, who, also, marker, but, what, kaohsiung,
# Nearest to most: more, many, among, some, especially, rockall, admirals, perpetually,
# Nearest to use: choreographer, lanterns, example, mailed, stills, odysseus, dropping, momentary,
# Nearest to are: were, have, is, these, lexical, savanna, although, amiable,
# Nearest to between: with, in, from, topsoil, among, christy, pulse, symonds,
# Average loss at step 32000: 3.505431
# Average loss at step 34000: 3.490955
# Average loss at step 36000: 3.455185
# Average loss at step 38000: 3.302055
# Average loss at step 40000: 3.426798
# Nearest to if: when, where, though, etruria, before, is, adverbs, because,
# Nearest to had: has, have, was, were, been, peacock, teau, possessed,
# Nearest to two: three, four, five, six, seven, eight, one, nine,
# Nearest to with: between, fukuoka, when, using, by, cleave, on, duration,
# Nearest to was: is, were, became, had, has, been, be, splash,
# Nearest to to: screenshot, jeb, will, implicate, dmitry, tempos, cloudy, reopen,
# Nearest to new: maximian, repeaters, profiled, gripped, ona, metal, collection, flow,
# Nearest to its: their, his, the, her, ctus, tarn, hearn, pierced,
# Nearest to into: from, intensification, through, dartmoor, wiens, theroux, ankara, bronzes,
# Nearest to nine: eight, seven, six, five, four, zero, three, one,
# Nearest to these: many, some, several, such, they, all, both, those,
# Nearest to which: that, this, also, who, there, it, actually, often,
# Nearest to most: more, among, especially, many, very, approx, hieroglyph, hiatus,
# Nearest to use: choreographer, lanterns, example, mailed, strategic, astonishing, hard, sheath,
# Nearest to are: were, have, is, amiable, be, fathoms, these, shehhi,
# Nearest to between: with, among, within, over, vedic, from, symonds, pulse,
# Average loss at step 42000: 3.437390
# Average loss at step 44000: 3.444968
# Average loss at step 46000: 3.449705
# Average loss at step 48000: 3.349858
# Average loss at step 50000: 3.380973
# Nearest to if: when, where, though, before, although, so, fry, while,
# Nearest to had: has, have, were, was, having, possessed, under, been,
# Nearest to two: three, four, one, six, five, seven, eight, zero,
# Nearest to with: between, transcript, using, by, cherokee, cui, essences, nicotine,
# Nearest to was: is, has, became, were, had, be, been, by,
# Nearest to to: implicate, screenshot, xx, could, specially, would, might, may,
# Nearest to new: profiled, philippines, unaccustomed, iast, sindhu, bust, aelius, different,
# Nearest to its: their, his, the, her, nyse, hearn, tarn, jezreel,
# Nearest to into: through, out, intensification, from, theroux, on, dartmoor, over,
# Nearest to nine: eight, seven, six, zero, four, five, three, one,
# Nearest to these: some, many, such, several, both, those, various, different,
# Nearest to which: that, this, who, also, often, what, ia, now,
# Nearest to most: more, some, especially, less, many, among, approx, very,
# Nearest to use: form, lanterns, brugge, choreographer, sheath, astonishing, catastrophe, most,
# Nearest to are: were, is, have, amiable, being, although, shear, be,
# Nearest to between: with, among, within, montoneros, across, in, heapsort, archaeologists,
# Average loss at step 52000: 3.435364
# Average loss at step 54000: 3.427764
# Average loss at step 56000: 3.439389
# Average loss at step 58000: 3.396182
# Average loss at step 60000: 3.391732
# Nearest to if: when, where, though, before, then, because, so, since,
# Nearest to had: has, have, was, were, having, been, peacock, gave,
# Nearest to two: four, three, six, five, one, eight, seven, zero,
# Nearest to with: between, fukuoka, using, when, essences, by, nicotine, koizumi,
# Nearest to was: is, became, had, were, has, been, be, although,
# Nearest to to: screenshot, would, may, will, implicate, abkhazians, jeb, t,
# Nearest to new: profiled, bust, different, inwo, unaccustomed, surfacing, particular, crandall,
# Nearest to its: their, his, the, her, plosives, paragraph, pantheistic, my,
# Nearest to into: through, from, over, out, theroux, intensification, ankara, dartmoor,
# Nearest to nine: eight, seven, six, four, five, zero, three, one,
# Nearest to these: some, many, several, those, both, such, all, different,
# Nearest to which: that, this, what, who, these, there, however, amounted,
# Nearest to most: more, many, especially, some, less, among, approx, hiatus,
# Nearest to use: brugge, sheath, submits, accept, lanterns, most, astonishing, because,
# Nearest to are: were, is, have, amiable, including, be, staggering, include,
# Nearest to between: among, with, montoneros, within, trojan, heapsort, pulse, over,
# Average loss at step 62000: 3.241500
# Average loss at step 64000: 3.263002
# Average loss at step 66000: 3.403275
# Average loss at step 68000: 3.391400
# Average loss at step 70000: 3.356396
# Nearest to if: when, though, where, before, while, although, because, after,
# Nearest to had: has, have, was, having, were, peacock, been, gave,
# Nearest to two: three, four, six, one, five, seven, eight, zero,
# Nearest to with: between, fukuoka, using, when, by, koizumi, into, sour,
# Nearest to was: is, were, became, had, has, be, been, wore,
# Nearest to to: will, can, screenshot, would, must, implicate, may, tempos,
# Nearest to new: different, bust, profiled, evoke, crandall, surfacing, etat, inwo,
# Nearest to its: their, his, the, her, nyse, whose, tarn, hearn,
# Nearest to into: through, from, intensification, theroux, dartmoor, in, with, ankara,
# Nearest to nine: eight, seven, six, five, zero, four, three, one,
# Nearest to these: some, such, many, the, they, which, several, those,
# Nearest to which: that, this, actually, what, also, these, who, but,
# Nearest to most: more, less, many, some, especially, particularly, very, among,
# Nearest to use: form, most, think, astonishing, cause, lanterns, ascend, sclerosis,
# Nearest to are: were, is, amiable, have, be, including, although, include,
# Nearest to between: among, within, with, montoneros, anode, trojan, across, heapsort,
# Average loss at step 72000: 3.369949
# Average loss at step 74000: 3.345889
# Average loss at step 76000: 3.313598
# Average loss at step 78000: 3.349721
# Average loss at step 80000: 3.378427
# Nearest to if: when, before, though, where, then, because, since, although,
# Nearest to had: has, have, were, having, was, peacock, been, gave,
# Nearest to two: three, four, six, five, one, seven, eight, isbn,
# Nearest to with: between, fukuoka, koizumi, brummell, in, into, when, sour,
# Nearest to was: is, became, were, has, had, been, splash, delays,
# Nearest to to: implicate, would, will, can, screenshot, for, should, automotive,
# Nearest to new: different, bust, heydrich, evoke, single, menezes, paraphrased, plead,
# Nearest to its: their, his, her, the, your, my, pantheistic, desylva,
# Nearest to into: through, from, entire, within, intensification, over, with, theroux,
# Nearest to nine: eight, seven, five, six, four, zero, three, cet,
# Nearest to these: several, many, both, some, such, those, various, they,
# Nearest to which: that, this, usually, also, actually, these, often, what,
# Nearest to most: many, some, more, especially, less, among, particularly, very,
# Nearest to use: list, form, think, cause, thinking, refer, because, sense,
# Nearest to are: were, is, have, amiable, include, sundays, although, complexion,
# Nearest to between: within, among, with, over, from, montoneros, in, heapsort,
# Average loss at step 82000: 3.407382
# Average loss at step 84000: 3.405754
# Average loss at step 86000: 3.388636
# Average loss at step 88000: 3.352198
# Average loss at step 90000: 3.361788
# Nearest to if: when, though, before, where, since, although, after, so,
# Nearest to had: has, have, was, were, having, peacock, since, been,
# Nearest to two: three, four, five, six, one, eight, seven, nine,
# Nearest to with: between, fukuoka, harman, reordering, by, koizumi, using, nicotine,
# Nearest to was: is, had, became, were, has, been, be, delays,
# Nearest to to: would, implicate, will, instituting, screenshot, adrenal, flanking, abkhazians,
# Nearest to new: different, particular, crandall, editing, profiled, copa, vigorous, surfacing,
# Nearest to its: their, his, her, the, your, whose, pantheistic, nyse,
# Nearest to into: through, from, within, underarm, targeting, around, over, intensification,
# Nearest to nine: eight, seven, five, six, four, zero, three, two,
# Nearest to these: several, some, many, such, those, various, are, both,
# Nearest to which: that, this, also, what, but, actually, amounted, these,
# Nearest to most: more, some, less, many, especially, several, among, particularly,
# Nearest to use: list, need, reinvention, cause, because, phrygia, share, form,
# Nearest to are: were, is, have, include, amiable, these, tiglath, sweetened,
# Nearest to between: within, among, with, over, across, through, from, montoneros,
# Average loss at step 92000: 3.403630
# Average loss at step 94000: 3.247445
# Average loss at step 96000: 3.354261
# Average loss at step 98000: 3.241608
# Average loss at step 100000: 3.353884
# Nearest to if: when, though, before, where, because, so, for, since,
# Nearest to had: has, have, having, was, were, peacock, since, yet,
# Nearest to two: four, three, five, six, seven, one, eight, zero,
# Nearest to with: between, including, koizumi, at, essences, using, nicotine, fukuoka,
# Nearest to was: is, became, has, were, had, been, nanometres, although,
# Nearest to to: will, implicate, would, could, can, must, should, screenshot,
# Nearest to new: different, profiled, vigorous, nautical, crandall, basic, codebreaking, cub,
# Nearest to its: their, his, the, her, pantheistic, your, chadic, blatantly,
# Nearest to into: through, within, from, out, over, around, onto, husky,
# Nearest to nine: eight, seven, six, four, five, zero, three, two,
# Nearest to these: some, several, many, various, which, those, all, multiple,
# Nearest to which: that, this, actually, these, what, usually, who, however,
# Nearest to most: more, less, especially, particularly, some, many, among, several,
# Nearest to use: cause, form, need, list, phrygia, astonishing, most, reinvention,
# Nearest to are: were, have, amiable, be, is, these, those, although,
# Nearest to between: among, within, with, across, trojan, through, over, against,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %% [markdown]
# ## USE Gensim Word2Vec

# %% [markdown]
# word2vec将单词转换为向量。使得相似的单词的向量表示相近。可以是语义上的相似度和语法上的相似度。

# %% [markdown]
# ###### 官方网站：gensim word2vec model: http://radimrehurek.com/gensim/models/word2vec.html

# %%
# import modules and set up logging
from gensim.models import word2vec, KeyedVectors
# import logging
# logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
# load up unzipped corpus from http://mattmahoney.net/dc/text8.zip
sentences = word2vec.Text8Corpus('text8')

# %%
# train the skip-gram model; default window=5
model = word2vec.Word2Vec(
    sentences,
    sg = 1, # 1 use skip-gram model， 0 use CBOW
    iter = 5, # epoch is 5 times, total run 6 times
    seed = 1,  #  seed
    size = 200, # word2vev 中 vec 的 length， 通常在100到1000之间，默认为100
    window =7, #  word left and right
    workers = 1, # 用于设置并发训练时候的线程数，仅当Cython安装的情况下才会起作用,defent is 1
)
# Out:
# 2017-03-12 15:28:42,762 : INFO : collecting all words and their counts
# 2017-03-12 15:28:42,772 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2017
words/s, in_qsize 6, out_qsize 1
# 2017-03-12 15:36:26,125 : INFO : PROGRESS: at 96.04% examples, 133613 words/s, in_qsize 6, out_qsize 0
# 2017-03-12 15:36:27,282 : INFO : PROGRESS: at 96.24% examples, 133546 words/s, in_qsize 6, out_qsize 0
# 2017-03-12 15:36:28,363 : INFO : PROGRESS: at 96.44% examples, 133501 words/s, in_qsize 6, out_qsize 0
# 2017-03-12 15:36:29,463 : INFO : PROGRESS: at 96.61% examples, 133419 words/s, in_qsize 5, out_qsize 0
# 2017-03-12 15:36:30,496 : INFO : PROGRESS: at 96.79% examples, 133369 words/s, in_qsize 6, out_qsize 1
# 2017-03-12 15:36:31,488 : INFO : PROGRESS: at 96.98% examples, 133328 words/s, in_qsize 5, out_qsize 0
# 2017-03-12 15:36:32,638 : INFO : PROGRESS: at 97.14% examples, 133219 words/s, in_qsize 6, out_qsize 0
# 2017-03-12 15:36:33,843 : INFO : PROGRESS: at 97.25% examples, 133012 words/s, in_qsize 6, out_qsize 0
# 2017-03-12 15:36:34,931 : INFO : PROGRESS: at 97.43% examples, 132935 words/s, in_qsize 6, out_qsize 0
# 2017-03-12 15:36:36,003 : INFO : PROGRESS: at 97.59% examples, 132852 words/s, in_qsize 6, out_qsize 0
# 2017-03-12 15:36:37,015 : INFO : PROGRESS: at 97.75% examples, 132782 words/s, in_qsize 5, out_qsize 0
# 2017-03-12 15:36:38,077 : INFO : PROGRESS: at 97.92% examples, 132703 words/s, in_qsize 6, out_qsize 0
# 2017-03-12 15:36:39,126 : INFO : PROGRESS: at 98.11% examples, 132659 words/s, in_qsize 5, out_qsize 0
# 2017-03-12 15:36:40,224 : INFO : PROGRESS: at 98.32% examples, 132624 words/s, in_qsize 6, out_qsize 1
# 2017-03-12 15:36:41,252 : INFO : PROGRESS: at 98.50% examples, 132564 words/s, in_qsize 5, out_qsize 0
# 2017-03-12 15:36:42,258 : INFO : PROGRESS: at 98.68% examples, 132529 words/s, in_qsize 6, out_qsize 0
# 2017-03-12 15:36:43,309 : INFO : PROGRESS: at 98.87% examples, 132486 words/s, in_qsize 5, out_qsize 0
# 2017-03-12 15:36:44,360 : INFO : PROGRESS: at 99.06% examples, 132435 words/s, in_qsize 6, out_qsize 0
# 2017-03-12 15:36:45,384 : INFO : PROGRESS: at 99.27% examples, 132428 words/s, in_qsize 6, out_qsize 0
# 2017-03-12 15:36:46,396 : INFO : PROGRESS: at 99.44% examples, 132358 words/s, in_qsize 5, out_qsize 0
# 2017-03-12 15:36:47,414 : INFO : PROGRESS: at 99.67% examples, 132380 words/s, in_qsize 6, out_qsize 0
# 2017-03-12 15:36:48,434 : INFO : PROGRESS: at 99.87% examples, 132361 words/s, in_qsize 6, out_qsize 0
# 2017-03-12 15:36:48,867 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2017-03-12 15:36:48,870 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2017-03-12 15:36:48,919 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2017-03-12 15:36:48,921 : INFO : training on 85026035 raw words (62534100 effective words) took 472.3s, 132392 effective words/s

# %%
# pickle the entire model to disk, so we can load&resume training later
model.save('text8.model')
# Out:
# 2017-03-12 15:53:58,113 : INFO : saving Word2Vec object under text8.model, separately None
# 2017-03-12 15:53:58,115 : INFO : not storing attribute syn0norm
# 2017-03-12 15:53:58,116 : INFO : storing np array 'syn0' to text8.model.wv.syn0.npy
# 2017-03-12 15:53:58,336 : INFO : storing np array 'syn1neg' to text8.model.syn1neg.npy
# 2017-03-12 15:53:58,568 : INFO : not storing attribute cum_table
# 2017-03-12 15:54:00,467 : INFO : saved text8.model

# %%
model1 = word2vec.Word2Vec.load('text8.model')
# Out:
# 2017-03-12 16:00:49,889 : INFO : loading Word2Vec object from text8.model
# 2017-03-12 16:00:52,384 : INFO : loading wv recursively from text8.model.wv.* with mmap=None
# 2017-03-12 16:00:52,385 : INFO : loading syn0 from text8.model.wv.syn0.npy with mmap=None
# 2017-03-12 16:00:52,486 : INFO : setting ignored attribute syn0norm to None
# 2017-03-12 16:00:52,488 : INFO : loading syn1neg from text8.model.syn1neg.npy with mmap=None
# 2017-03-12 16:00:52,685 : INFO : setting ignored attribute cum_table to None
# 2017-03-12 16:00:52,688 : INFO : loaded text8.model

# %%
# store the learned weights, in a format the original C tool understands
model.wv.save_word2vec_format('text8.model.bin', binary=True)
# Out:
# 2017-03-12 15:15:56,009 : INFO : storing 71290x200 projection weights into text8.model.bin

# %%
# import word weights created by the (faster) C word2vec
# this way, you can switch between the C/Python toolkits easily
model = KeyedVectors.load_word2vec_format('text8.model.bin', binary=True)
# Out:
# 2017-03-12 15:18:19,525 : INFO : loading projection weights from text8.model.bin
# 2017-03-12 15:18:21,850 : INFO : loaded (71290, 200) matrix from text8.model.bin

# %%
model['computer'] # get the vector of word
# Out:
# array([  1.76507950e-01,  -5.50296232e-02,  -2.29498267e-01,
#          6.09016061e-01,  -1.19386390e-01,   2.37666294e-01,
#         -3.12807113e-01,   2.89961427e-01,   3.19655329e-01,
#         -5.38773537e-02,  -3.57174426e-01,   1.85477175e-02,
#         -1.17471680e-01,   1.41522124e-01,   3.13969791e-01,
#          2.34354548e-02,   3.84492092e-02,  -2.77660936e-01,
#         -2.05827013e-01,   1.36557743e-01,  -3.13636005e-01,
#          1.45617247e-01,   4.89155620e-01,   2.44792894e-01,
#          4.22376627e-03,   3.42874706e-01,  -5.10226702e-03,
#         -5.12918271e-02,  -1.09031618e-01,   1.96698368e-01,
#          2.12217510e-01,  -1.82054743e-01,  -4.01401035e-02,
#          1.57929182e-01,  -3.07600349e-01,  -8.97792578e-02,
#          1.27812669e-01,  -7.41495937e-03,  -3.97382081e-01,
#         -7.19049871e-01,   6.65974468e-02,  -4.18552719e-02,
#         -1.79571554e-01,   3.05625312e-02,   1.57862425e-01,
#         -4.04116929e-01,   1.73650175e-01,   2.78159715e-02,
#         -1.09442987e-01,   1.00981342e-02,  -3.26557010e-01,
#         -2.60633498e-01,  -4.78187859e-01,   4.37040403e-02,
#         -3.72692138e-01,   2.90083662e-02,  -4.92938831e-02,
#         -1.40418066e-02,   1.54332504e-01,  -1.03171505e-01,
#         -4.76837963e-01,  -1.36836559e-01,  -9.59887207e-02,
#          2.57570706e-02,   1.84983879e-01,  -5.86573541e-01,
#         -8.78226608e-02,   1.11587167e-01,   1.24730945e-01,
#          2.91641057e-01,  -2.27707207e-01,  -1.51421160e-01,
#          4.04346645e-01,  -1.58812314e-01,   1.17366746e-01,
#          3.65509093e-02,   6.63465932e-02,   4.65964019e-01,
#          2.18442783e-01,   4.27012503e-01,  -1.31404608e-01,
#         -1.55540764e-01,  -4.23814297e-01,  -1.69852808e-01,
#         -3.85808609e-02,  -5.45030594e-01,   2.77796715e-01,
#         -4.09178168e-01,   1.68496251e-01,  -6.93565086e-02,
#         -8.26575831e-02,   5.04914671e-02,  -1.19768806e-01,
#         -5.55936806e-02,   2.66883075e-01,   5.73805198e-02,
#          2.66035318e-01,   1.16686538e-01,  -9.42711979e-02,
#          1.01891086e-01,   4.80668694e-02,  -1.56127766e-01,
#         -2.69477218e-02,  -3.35056409e-02,   9.25090238e-02,
#         -9.73244198e-03,   1.94880441e-01,   1.71128530e-02,
#         -2.11916894e-01,  -2.41662368e-01,   1.08681567e-01,
#         -2.14969128e-01,  -1.52632117e-01,  -1.40223941e-02,
#         -5.87907314e-01,   1.61730945e-02,  -1.01376541e-01,
#          3.16470861e-02,  -1.30040171e-02,   1.95360005e-01,
#          5.02030015e-01,   2.10142564e-02,   1.83203936e-01,
#          1.47616670e-01,   3.62843394e-01,  -1.12379253e-01,
#         -1.90915823e-01,  -1.74731597e-01,  -5.36560565e-02,
#         -4.58104499e-02,   7.88821504e-02,   1.19160593e-01,
#          7.03214556e-02,  -2.12921817e-02,  -1.06168598e-01,
#          4.11725968e-01,  -2.04149529e-01,   8.32460374e-02,
#         -4.01199967e-01,   2.81402260e-01,   1.45484060e-01,
#         -3.29174578e-01,   3.62025797e-01,  -2.70720690e-01,
#          1.78475678e-01,   5.84533960e-02,  -4.17353690e-01,
#          3.45121741e-01,  -8.61544162e-02,  -3.31108272e-01,
#          1.09222665e-01,   6.47296384e-02,   2.90808022e-01,
#          1.52335688e-01,   4.39450145e-03,   6.12782955e-01,
#         -1.78335067e-02,  -1.52967952e-03,  -3.32663894e-01,
#         -5.54404259e-01,  -2.85344541e-01,   1.43529639e-01,
#         -1.33518994e-01,  -6.06034040e-01,  -5.65226488e-02,
#         -5.61446510e-02,  -6.09211981e-01,   2.40779761e-02,
#          5.09803236e-01,   7.47216400e-04,   4.00130719e-01,
#         -3.18380862e-01,   1.18675955e-01,  -4.06671762e-02,
#          2.21825428e-02,   8.13892707e-02,   4.86400247e-01,
#          1.15265273e-01,   5.79115301e-02,   1.95884407e-01,
#          2.27044940e-01,  -1.96766034e-01,  -1.20703354e-02,
#          1.92060784e-01,   2.16737568e-01,   1.23128287e-01,
#          5.26589155e-01,  -3.17773372e-01,   6.12877905e-01,
#          2.85309851e-01,   2.86916077e-01,  -9.47866142e-01,
#         -5.40352985e-02,   1.47566348e-02,   3.37078780e-01,
#          1.77925184e-01,  -2.99390499e-02,   4.35829833e-02,
#         -3.85378391e-01,  -2.53392905e-01], dtype=float32)

# %%
# "boy" is to "father" as "girl" is to ...?
model_bin.most_similar(positive=['girl', 'father'],  negative=['boy'], topn=2)
# Out:
# [(u'mother', 0.7808817028999329), (u'wife', 0.7247772812843323)]

# %%
more_examples = ["he his she", "big bigger bad", "going went being"]
for example in more_examples:
    a, b, x = example.split()
    predicted = model.most_similar([x, b], [a])[0][0]
    print("'%s' is to '%s' as '%s' is to '%s'"%(a, b, x, predicted))
# Out:
# 'he' is to 'his' as 'she' is to 'her'
# 'big' is to 'bigger' as 'bad' is to 'worse'
# 'going' is to 'went' as 'being' is to 'was'

# %%
# which word doesn't go with the others?
model_bin.doesnt_match("breakfast cereal dinner lunch".split())
# Out:
# 'cereal'

# %%
model.similarity('woman', 'man')
# Out:
# 0.58688427176013747

# %%
model.most_similar(['man'])
# Out:
# 2017-03-12 16:03:52,907 : INFO : precomputing L2-norms of word weight vectors
# [(u'woman', 0.5868842601776123),
#  (u'luckiest', 0.58011394739151),
#  (u'shaves', 0.5776397585868835),
#  (u'awakens', 0.5670865178108215),
#  (u'madman', 0.5662087798118591),
#  (u'amnesiac', 0.5537807941436768),
#  (u'silenus', 0.5529398322105408),
#  (u'beast', 0.5506160259246826),
#  (u'molested', 0.5503117442131042),
#  (u'irishman', 0.5487006306648254)]
